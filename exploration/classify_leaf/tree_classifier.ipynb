# %%
import os
import pickle
from pathlib import Path

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from keras.layers import Dense, GlobalAveragePooling2D, Conv2D, Dropout
from keras.applications import MobileNet
from keras.preprocessing import image
from keras.applications.mobilenet import preprocess_input
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Model
from keras.optimizers import Adam

# %%
def load_img_and_transfer(img_path, target_size=(224, 224), im_show=False):
    img = image.load_img(img_path, target_size=target_size)
    x = image.img_to_array(img)
    x = np.expand_dims(x, axis=0)
    x = preprocess_input(x)
    if im_show:
        plt.imshow(img)
        plt.show()
    return x

# %%
base_model=MobileNet(weights='imagenet',include_top=False)
x=base_model.output
x=GlobalAveragePooling2D()(x)
# x=Dense(1024,activation='relu')(x)
# x=Dense(1024,activation='relu')(x)
x=Dense(512,activation='relu')(x)
x=Dropout(rate=0.3)(x)
preds=Dense(2,activation='softmax')(x)

# %%
model=Model(inputs=base_model.input,outputs=preds)

# %%
# Fix the weights for all layers except the last one
for layer in model.layers[:-3]:
    layer.trainable=False

# %%
model.compile(optimizer='Adam',loss='categorical_crossentropy',metrics=['accuracy'])

# %%
img_datagen=ImageDataGenerator(preprocessing_function=preprocess_input, validation_split=0.3) #included in our dependencies

train_generator=img_datagen.flow_from_directory('./data/raw',
                                                target_size=(224,224),
                                                color_mode='rgb',
                                                batch_size=64,
                                                class_mode='categorical',
                                                shuffle=True,
                                                subset='training')
# Out:
# Found 797 images belonging to 2 classes.

# %%
test_generator=img_datagen.flow_from_directory('./data/raw',
                                               target_size=(224,224),
                                               color_mode='rgb',
                                               batch_size=64,
                                               class_mode='categorical',
                                               shuffle=True,
                                               subset='validation')
# Out:
# Found 340 images belonging to 2 classes.

# %%
# Adam optimizer
# loss function will be categorical cross entropy
# evaluation metric will be accuracy

# TODO: increase epochs to 50, 100, 1000
step_size_train=train_generator.n//train_generator.batch_size
history = model.fit_generator(generator=train_generator,
                              validation_data=test_generator,
                              steps_per_epoch=step_size_train,
                              epochs=100)
# Out:
# WARNING:tensorflow:From /Users/aodanx/opt/anaconda3/envs/tree-classifier/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/100
# 12/12 [==============================] - 28s 2s/step - loss: 0.4081 - accuracy: 0.8308 - val_loss: 0.0342 - val_accuracy: 0.9618
# Epoch 2/100
# 12/12 [==============================] - 28s 2s/step - loss: 0.2232 - accuracy: 0.9168 - val_loss: 0.0268 - val_accuracy: 0.9471
# Epoch 3/100
# 12/12 [==============================] - 28s 2s/step - loss: 0.1907 - accuracy: 0.9222 - val_loss: 0.2114 - val_accuracy: 0.9706
# Epoch 4/100
# 12/12 [==============================] - 28s 2s/step - loss: 0.1713 - accuracy: 0.9304 - val_loss: 0.1361 - val_accuracy: 0.9500
# Epoch 5/100
# 12/12 [==============================] - 28s 2s/step - loss: 0.0815 - accuracy: 0.9727 - val_loss: 0.1192 - val_accuracy: 0.9559
# Epoch 6/100
# 12/12 [==============================] - 29s 2s/step - loss: 0.0560 - accuracy: 0.9754 - val_loss: 0.0325 - val_accuracy: 0.9618
# Epoch 7/100
# 12/12 [==============================] - 29s 2s/step - loss: 0.0430 - accuracy: 0.9870 - val_loss: 0.0620 - val_accuracy: 0.9676
# Epoch 8/100
# 12/12 [==============================] - 28s 2s/step - loss: 0.0303 - accuracy: 0.9918 - val_loss: 0.0467 - val_accuracy: 0.9588
# Epoch 9/100
# 12/12 [==============================] - 28s 2s/step - loss: 0.0452 - accuracy: 0.9877 - val_loss: 0.0455 - val_accuracy: 0.9647
# Epoch 10/100
# 12/12 [==============================] - 28s 2s/step - loss: 0.0193 - accuracy: 0.9959 - val_loss: 0.0076 - val_accuracy: 0.9647
# Epoch 11/100
# 12/12 [==============================] - 27s 2s/step - loss: 0.0151 - accuracy: 0.9986 - val_loss: 0.2649 - val_accuracy: 0.9647
# Epoch 12/100
# 12/12 [==============================] - 30s 2s/step - loss: 0.0322 - accuracy: 0.9883 - val_loss: 0.0500 - val_accuracy: 0.9647
# Epoch 13/100
# 12/12 [==============================] - 28s 2s/step - loss: 0.0193 - accuracy: 0.9959 - val_loss: 0.0225 - val_accuracy: 0.9412
# Epoch 14/100
# 12/12 [==============================] - 28s 2s/step - loss: 0.0202 - accuracy: 0.9932 - val_loss: 0.1824 - val_accuracy: 0.9647
# Epoch 15/100
# 12/12 [==============================] - 28s 2s/step - loss: 0.0154 - accuracy: 0.9973 - val_loss: 0.3099 - val_accuracy: 0.9618
# Epoch 16/100
# 12/12 [==============================] - 28s 2s/step - loss: 0.0089 - accuracy: 0.9986 - val_loss: 0.2365 - val_accuracy: 0.9618
# Epoch 17/100
# 12/12 [==============================] - 28s 2s/step - loss: 0.0081 - accuracy: 1.0000 - val_loss: 0.0672 - val_accuracy: 0.9647
# Epoch 18/100
# 12/12 [==============================] - 28s 2s/step - loss: 0.0076 - accuracy: 0.9986 - val_loss: 0.0236 - val_accuracy: 0.9676
# Epoch 19/100
# 12/12 [==============================] - 29s 2s/step - loss: 0.0065 - accuracy: 0.9986 - val_loss: 0.0810 - val_accuracy: 0.9294
# Epoch 20/100
# 12/12 [==============================] - 30s 3s/step - loss: 0.0088 - accuracy: 0.9987 - val_loss: 0.0365 - val_accuracy: 0.9559
# Epoch 21/100
# 12/12 [==============================] - 27s 2s/step - loss: 0.0100 - accuracy: 0.9957 - val_loss: 0.3279 - val_accuracy: 0.9618
# Epoch 22/100
# 12/12 [==============================] - 30s 2s/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.0492 - val_accuracy: 0.9588
# Epoch 23/100
# 12/12 [==============================] - 30s 3s/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.0012 - val_accuracy: 0.9559
# Epoch 24/100
# 12/12 [==============================] - 36s 3s/step - loss: 0.0051 - accuracy: 1.0000 - val_loss: 0.2101 - val_accuracy: 0.9676
# Epoch 25/100
# 12/12 [==============================] - 29s 2s/step - loss: 0.0043 - accuracy: 0.9986 - val_loss: 0.0527 - val_accuracy: 0.9529
# Epoch 26/100
# 12/12 [==============================] - 27s 2s/step - loss: 0.0066 - accuracy: 0.9986 - val_loss: 4.8935e-04 - val_accuracy: 0.9676
# Epoch 27/100
# 12/12 [==============================] - 28s 2s/step - loss: 0.0045 - accuracy: 1.0000 - val_loss: 0.0228 - val_accuracy: 0.9618
# Epoch 28/100
# 12/12 [==============================] - 29s 2s/step - loss: 0.0047 - accuracy: 0.9987 - val_loss: 0.0224 - val_accuracy: 0.9618
# Epoch 29/100
# 12/12 [==============================] - 28s 2s/step - loss: 0.0325 - accuracy: 0.9891 - val_loss: 0.0665 - val_accuracy: 0.9059
# Epoch 30/100
# 12/12 [==============================] - 27s 2s/step - loss: 0.0267 - accuracy: 0.9871 - val_loss: 0.1097 - val_accuracy: 0.9324
# Epoch 31/100
# 12/12 [==============================] - 28s 2s/step - loss: 0.0350 - accuracy: 0.9891 - val_loss: 0.0107 - val_accuracy: 0.9029
# Epoch 32/100
# 12/12 [==============================] - 29s 2s/step - loss: 0.0373 - accuracy: 0.9857 - val_loss: 0.4491 - val_accuracy: 0.8941
# Epoch 33/100
# 12/12 [==============================] - 27s 2s/step - loss: 0.0334 - accuracy: 0.9914 - val_loss: 0.7365 - val_accuracy: 0.8853
# Epoch 34/100
# 12/12 [==============================] - 29s 2s/step - loss: 0.0267 - accuracy: 0.9864 - val_loss: 0.0919 - val_accuracy: 0.9206
# Epoch 35/100
# 12/12 [==============================] - 30s 2s/step - loss: 0.0275 - accuracy: 0.9883 - val_loss: 0.0020 - val_accuracy: 0.9618
# Epoch 36/100
# 12/12 [==============================] - 28s 2s/step - loss: 0.0623 - accuracy: 0.9754 - val_loss: 0.0033 - val_accuracy: 0.9588
# Epoch 37/100
# 12/12 [==============================] - 28s 2s/step - loss: 0.0924 - accuracy: 0.9556 - val_loss: 0.3238 - val_accuracy: 0.9647
# Epoch 38/100
# 12/12 [==============================] - 31s 3s/step - loss: 0.1146 - accuracy: 0.9622 - val_loss: 0.0018 - val_accuracy: 0.9559
# Epoch 39/100
# 12/12 [==============================] - 36s 3s/step - loss: 0.0364 - accuracy: 0.9850 - val_loss: 0.0561 - val_accuracy: 0.9500
# Epoch 40/100
# 12/12 [==============================] - 30s 2s/step - loss: 0.0073 - accuracy: 0.9974 - val_loss: 0.4598 - val_accuracy: 0.9471
# Epoch 41/100
# 12/12 [==============================] - 27s 2s/step - loss: 0.0047 - accuracy: 1.0000 - val_loss: 0.1988 - val_accuracy: 0.9382
# Epoch 42/100
# 12/12 [==============================] - 28s 2s/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.3793 - val_accuracy: 0.9412
# Epoch 43/100
# 12/12 [==============================] - 28s 2s/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.0043 - val_accuracy: 0.9529
# Epoch 44/100
# 12/12 [==============================] - 28s 2s/step - loss: 0.0038 - accuracy: 0.9986 - val_loss: 0.4311 - val_accuracy: 0.9353
# Epoch 45/100
# 12/12 [==============================] - 27s 2s/step - loss: 0.0171 - accuracy: 0.9945 - val_loss: 0.4409 - val_accuracy: 0.9265
# Epoch 46/100
# 12/12 [==============================] - 29s 2s/step - loss: 0.0135 - accuracy: 0.9959 - val_loss: 0.0811 - val_accuracy: 0.9412
# Epoch 47/100
# 12/12 [==============================] - 28s 2s/step - loss: 0.0048 - accuracy: 0.9986 - val_loss: 0.2359 - val_accuracy: 0.9324
# Epoch 48/100
# 12/12 [==============================] - 28s 2s/step - loss: 0.0108 - accuracy: 0.9986 - val_loss: 0.4410 - val_accuracy: 0.9088
# Epoch 49/100
# 12/12 [==============================] - 29s 2s/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.3331 - val_accuracy: 0.9353
# Epoch 50/100
# 12/12 [==============================] - 29s 2s/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.2243 - val_accuracy: 0.9441
# Epoch 51/100
# 12/12 [==============================] - 28s 2s/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.0918 - val_accuracy: 0.9441
# Epoch 52/100
# 12/12 [==============================] - 28s 2s/step - loss: 8.2273e-04 - accuracy: 1.0000 - val_loss: 0.0032 - val_accuracy: 0.9412
# Epoch 53/100
# 12/12 [==============================] - 28s 2s/step - loss: 0.0041 - accuracy: 0.9986 - val_loss: 0.2384 - val_accuracy: 0.9441
# Epoch 54/100
# 12/12 [==============================] - 28s 2s/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.2139 - val_accuracy: 0.9412
# Epoch 55/100
# 12/12 [==============================] - 29s 2s/step - loss: 0.0027 - accuracy: 0.9987 - val_loss: 0.0965 - val_accuracy: 0.9412
# Epoch 56/100
# 12/12 [==============================] - 27s 2s/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1345 - val_accuracy: 0.9353
# Epoch 57/100
# 12/12 [==============================] - 28s 2s/step - loss: 6.3767e-04 - accuracy: 1.0000 - val_loss: 0.2379 - val_accuracy: 0.9441
# Epoch 58/100
# 12/12 [==============================] - 27s 2s/step - loss: 9.3131e-04 - accuracy: 1.0000 - val_loss: 0.5843 - val_accuracy: 0.9412
# Epoch 59/100
# 12/12 [==============================] - 28s 2s/step - loss: 0.0017 - accuracy: 0.9987 - val_loss: 0.1614 - val_accuracy: 0.9353
# Epoch 60/100
# 12/12 [==============================] - 27s 2s/step - loss: 0.0015 - accuracy: 0.9986 - val_loss: 0.4067 - val_accuracy: 0.9412
# Epoch 61/100
# 12/12 [==============================] - 29s 2s/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0075 - val_accuracy: 0.9441
# Epoch 62/100
# 12/12 [==============================] - 28s 2s/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.1380 - val_accuracy: 0.9353
# Epoch 63/100
# 12/12 [==============================] - 28s 2s/step - loss: 0.0023 - accuracy: 0.9986 - val_loss: 0.7154 - val_accuracy: 0.9412
# Epoch 64/100
# 12/12 [==============================] - 28s 2s/step - loss: 0.0031 - accuracy: 0.9986 - val_loss: 0.4681 - val_accuracy: 0.9471
# Epoch 65/100
# 12/12 [==============================] - 28s 2s/step - loss: 0.0030 - accuracy: 0.9986 - val_loss: 0.3412 - val_accuracy: 0.9353
# Epoch 66/100
# 12/12 [==============================] - 28s 2s/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.2233 - val_accuracy: 0.9441
# Epoch 67/100
# 12/12 [==============================] - 29s 2s/step - loss: 0.0053 - accuracy: 0.9986 - val_loss: 0.5486 - val_accuracy: 0.9235
# Epoch 68/100
# 12/12 [==============================] - 28s 2s/step - loss: 0.0084 - accuracy: 0.9986 - val_loss: 0.2298 - val_accuracy: 0.9382
# Epoch 69/100
# 12/12 [==============================] - 29s 2s/step - loss: 0.0045 - accuracy: 0.9987 - val_loss: 0.1356 - val_accuracy: 0.9412
# Epoch 70/100
# 12/12 [==============================] - 28s 2s/step - loss: 0.0040 - accuracy: 0.9986 - val_loss: 0.3583 - val_accuracy: 0.9206
# Epoch 71/100
# 12/12 [==============================] - 29s 2s/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0968 - val_accuracy: 0.9500
# Epoch 72/100
# 12/12 [==============================] - 28s 2s/step - loss: 0.0039 - accuracy: 0.9986 - val_loss: 0.0021 - val_accuracy: 0.9382
# Epoch 73/100
# 12/12 [==============================] - 28s 2s/step - loss: 0.0071 - accuracy: 0.9973 - val_loss: 0.0158 - val_accuracy: 0.9412
# Epoch 74/100
# 12/12 [==============================] - 29s 2s/step - loss: 8.5308e-04 - accuracy: 1.0000 - val_loss: 0.0241 - val_accuracy: 0.9412
# Epoch 75/100
# 12/12 [==============================] - 28s 2s/step - loss: 8.7635e-04 - accuracy: 1.0000 - val_loss: 0.4596 - val_accuracy: 0.9441
# Epoch 76/100
# 12/12 [==============================] - 28s 2s/step - loss: 4.7816e-04 - accuracy: 1.0000 - val_loss: 0.0344 - val_accuracy: 0.9441
# Epoch 77/100
# 12/12 [==============================] - 28s 2s/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.0165 - val_accuracy: 0.9441
# Epoch 78/100
# 12/12 [==============================] - 28s 2s/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.1621 - val_accuracy: 0.9441
# Epoch 79/100
# 12/12 [==============================] - 28s 2s/step - loss: 2.6200e-04 - accuracy: 1.0000 - val_loss: 0.4951 - val_accuracy: 0.9353
# Epoch 80/100
# 12/12 [==============================] - 29s 2s/step - loss: 8.1977e-04 - accuracy: 1.0000 - val_loss: 0.1198 - val_accuracy: 0.9412
# Epoch 81/100
# 12/12 [==============================] - 28s 2s/step - loss: 3.0644e-04 - accuracy: 1.0000 - val_loss: 0.6084 - val_accuracy: 0.9441
# Epoch 82/100
# 12/12 [==============================] - 28s 2s/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.0637 - val_accuracy: 0.9147
# Epoch 83/100
# 12/12 [==============================] - 28s 2s/step - loss: 0.0201 - accuracy: 0.9945 - val_loss: 1.3052 - val_accuracy: 0.8441
# Epoch 84/100
# 12/12 [==============================] - 29s 2s/step - loss: 0.0308 - accuracy: 0.9905 - val_loss: 0.0389 - val_accuracy: 0.9500
# Epoch 85/100
# 12/12 [==============================] - 29s 2s/step - loss: 0.0519 - accuracy: 0.9805 - val_loss: 0.7678 - val_accuracy: 0.9412
# Epoch 86/100
# 12/12 [==============================] - 28s 2s/step - loss: 0.1879 - accuracy: 0.9456 - val_loss: 0.0205 - val_accuracy: 0.9353
# Epoch 87/100
# 12/12 [==============================] - 29s 2s/step - loss: 0.0380 - accuracy: 0.9831 - val_loss: 0.3403 - val_accuracy: 0.9294
# Epoch 88/100
# 12/12 [==============================] - 28s 2s/step - loss: 0.0139 - accuracy: 0.9945 - val_loss: 0.7453 - val_accuracy: 0.9147
# Epoch 89/100
# 12/12 [==============================] - 28s 2s/step - loss: 0.0089 - accuracy: 0.9973 - val_loss: 0.3160 - val_accuracy: 0.9324
# Epoch 90/100
# 12/12 [==============================] - 28s 2s/step - loss: 0.0042 - accuracy: 1.0000 - val_loss: 0.3514 - val_accuracy: 0.9382
# Epoch 91/100
# 12/12 [==============================] - 28s 2s/step - loss: 7.3891e-04 - accuracy: 1.0000 - val_loss: 1.1374 - val_accuracy: 0.9176
# Epoch 92/100
# 12/12 [==============================] - 28s 2s/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.5966 - val_accuracy: 0.9176
# Epoch 93/100
# 12/12 [==============================] - 29s 2s/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.1653 - val_accuracy: 0.9353
# Epoch 94/100
# 12/12 [==============================] - 28s 2s/step - loss: 9.4901e-04 - accuracy: 1.0000 - val_loss: 0.2513 - val_accuracy: 0.9353
# Epoch 95/100
# 12/12 [==============================] - 28s 2s/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.2905 - val_accuracy: 0.9294
# Epoch 96/100
# 12/12 [==============================] - 28s 2s/step - loss: 8.6543e-04 - accuracy: 1.0000 - val_loss: 0.3643 - val_accuracy: 0.9294
# Epoch 97/100
# 12/12 [==============================] - 30s 2s/step - loss: 9.9313e-04 - accuracy: 1.0000 - val_loss: 0.1562 - val_accuracy: 0.9147
# Epoch 98/100
# 12/12 [==============================] - 28s 2s/step - loss: 0.0041 - accuracy: 0.9986 - val_loss: 0.4778 - val_accuracy: 0.9353
# Epoch 99/100
# 12/12 [==============================] - 28s 2s/step - loss: 0.0026 - accuracy: 0.9986 - val_loss: 0.4914 - val_accuracy: 0.9382
# Epoch 100/100
# 12/12 [==============================] - 28s 2s/step - loss: 7.8978e-04 - accuracy: 1.0000 - val_loss: 0.0370 - val_accuracy: 0.9353

# %%
plt.plot(history.history['loss'], label='train_loss')
plt.plot(history.history['val_loss'], 'r', label='val_loss')
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend()
plt.show()

# %%
plt.plot(history.history['accuracy'], label='train_acc')
plt.plot(history.history['val_accuracy'], 'r', label='val_acc')
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend()
plt.show()

# %%
# Save weights of the model
model.save_weights('tree-classifier.h5')

# %% [markdown]
# # Image Augmentation

# %%
train_datagen = ImageDataGenerator(preprocessing_function=preprocess_input, 
                                   horizontal_flip=True,
                                   vertical_flip=True,
                                   rotation_range=40,
                                   brightness_range=(0.7,1.3),
                                   zoom_range=0.2) #included in our dependencies

train_generator = train_datagen.flow_from_directory('./data/processed/train',
                                                    target_size=(224,224),
                                                    color_mode='rgb',
                                                    batch_size=64,
                                                    class_mode='categorical',
                                                    shuffle=True)
# Out:
# Found 836 images belonging to 2 classes.

# %%
test_datagen = ImageDataGenerator(preprocessing_function=preprocess_input) #included in our dependencies
test_generator = test_datagen.flow_from_directory('./data/processed/test/',
                                                  target_size=(224,224),
                                                  color_mode='rgb',
                                                  batch_size=64,
                                                  class_mode='categorical',
                                                  shuffle=True)
# Out:
# Found 300 images belonging to 2 classes.

# %%
step_size_train=train_generator.n//train_generator.batch_size
history = model.fit_generator(generator=train_generator,
                              validation_data=test_generator,
                              steps_per_epoch=step_size_train,
                              epochs=10)
# Out:
# Epoch 1/10
# 26/26 [==============================] - 34s 1s/step - loss: 0.3031 - accuracy: 0.9042 - val_loss: 0.4455 - val_accuracy: 0.8833
# Epoch 2/10
# 26/26 [==============================] - 32s 1s/step - loss: 0.2254 - accuracy: 0.9192 - val_loss: 0.0557 - val_accuracy: 0.9633
# Epoch 3/10
# 26/26 [==============================] - 32s 1s/step - loss: 0.3019 - accuracy: 0.9067 - val_loss: 0.0013 - val_accuracy: 0.9333
# Epoch 4/10
# 26/26 [==============================] - 32s 1s/step - loss: 0.1266 - accuracy: 0.9515 - val_loss: 0.0834 - val_accuracy: 0.9767
# Epoch 5/10
# 26/26 [==============================] - 33s 1s/step - loss: 0.1630 - accuracy: 0.9391 - val_loss: 0.1421 - val_accuracy: 0.9500
# Epoch 6/10
# 26/26 [==============================] - 33s 1s/step - loss: 0.1549 - accuracy: 0.9403 - val_loss: 0.1104 - val_accuracy: 0.9567
# Epoch 7/10
# 26/26 [==============================] - 32s 1s/step - loss: 0.1626 - accuracy: 0.9328 - val_loss: 0.3594 - val_accuracy: 0.9600
# Epoch 8/10
# 26/26 [==============================] - 34s 1s/step - loss: 0.1048 - accuracy: 0.9577 - val_loss: 0.2545 - val_accuracy: 0.9633
# Epoch 9/10
# 26/26 [==============================] - 34s 1s/step - loss: 0.1373 - accuracy: 0.9543 - val_loss: 0.0083 - val_accuracy: 0.9533
# Epoch 10/10
# 26/26 [==============================] - 35s 1s/step - loss: 0.1340 - accuracy: 0.9433 - val_loss: 0.2274 - val_accuracy: 0.9567

# %%
step_size_train=train_generator.n//train_generator.batch_size
history = model.fit_generator(generator=train_generator,
                              validation_data=test_generator,
                              steps_per_epoch=step_size_train,
                              epochs=10)
# Out:
# Epoch 1/10
# 26/26 [==============================] - 38s 1s/step - loss: 0.1621 - accuracy: 0.9303 - val_loss: 0.4703 - val_accuracy: 0.9633
# Epoch 2/10
# 26/26 [==============================] - 38s 1s/step - loss: 0.0874 - accuracy: 0.9701 - val_loss: 0.0104 - val_accuracy: 0.9533
# Epoch 3/10
# 26/26 [==============================] - 37s 1s/step - loss: 0.1510 - accuracy: 0.9490 - val_loss: 0.0770 - val_accuracy: 0.9700
# Epoch 4/10
# 26/26 [==============================] - 37s 1s/step - loss: 0.1240 - accuracy: 0.9527 - val_loss: 0.3569 - val_accuracy: 0.9600
# Epoch 5/10
# 26/26 [==============================] - 38s 1s/step - loss: 0.0909 - accuracy: 0.9688 - val_loss: 0.0066 - val_accuracy: 0.9600
# Epoch 6/10
# 25/26 [===========================>..] - ETA: 1s - loss: 0.0693 - accuracy: 0.9745
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-22-3fc419699762> in <module>
#       3                               validation_data=test_generator,
#       4                               steps_per_epoch=step_size_train,
# ----> 5                               epochs=10)
#
# ~/opt/anaconda3/envs/tree-classifier/lib/python3.6/site-packages/keras/legacy/interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name + '` call to the ' +
#      90                               'Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# ~/opt/anaconda3/envs/tree-classifier/lib/python3.6/site-packages/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1730             use_multiprocessing=use_multiprocessing,
#    1731             shuffle=shuffle,
# -> 1732             initial_epoch=initial_epoch)
#    1733
#    1734     @interfaces.legacy_generator_methods_support
#
# ~/opt/anaconda3/envs/tree-classifier/lib/python3.6/site-packages/keras/engine/training_generator.py in fit_generator(model, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#     240                             validation_steps,
#     241                             callbacks=callbacks,
# --> 242                             workers=0)
#     243                     else:
#     244                         # No need for try/except because
#
# ~/opt/anaconda3/envs/tree-classifier/lib/python3.6/site-packages/keras/legacy/interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name + '` call to the ' +
#      90                               'Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# ~/opt/anaconda3/envs/tree-classifier/lib/python3.6/site-packages/keras/engine/training.py in evaluate_generator(self, generator, steps, callbacks, max_queue_size, workers, use_multiprocessing, verbose)
#    1789             workers=workers,
#    1790             use_multiprocessing=use_multiprocessing,
# -> 1791             verbose=verbose)
#    1792
#    1793     @interfaces.legacy_generator_methods_support
#
# ~/opt/anaconda3/envs/tree-classifier/lib/python3.6/site-packages/keras/engine/training_generator.py in evaluate_generator(model, generator, steps, callbacks, max_queue_size, workers, use_multiprocessing, verbose)
#     399             outs = model.test_on_batch(x, y,
#     400                                        sample_weight=sample_weight,
# --> 401                                        reset_metrics=False)
#     402             outs = to_list(outs)
#     403             outs_per_batch.append(outs)
#
# ~/opt/anaconda3/envs/tree-classifier/lib/python3.6/site-packages/keras/engine/training.py in test_on_batch(self, x, y, sample_weight, reset_metrics)
#    1557             ins = x + y + sample_weights
#    1558         self._make_test_function()
# -> 1559         outputs = self.test_function(ins)
#    1560
#    1561         if reset_metrics:
#
# ~/opt/anaconda3/envs/tree-classifier/lib/python3.6/site-packages/tensorflow/python/keras/backend.py in __call__(self, inputs)
#    3074
#    3075     fetched = self._callable_fn(*array_vals,
# -> 3076                                 run_metadata=self.run_metadata)
#    3077     self._call_fetch_callbacks(fetched[-len(self._fetches):])
#    3078     return nest.pack_sequence_as(self._outputs_structure,
#
# ~/opt/anaconda3/envs/tree-classifier/lib/python3.6/site-packages/tensorflow/python/client/session.py in __call__(self, *args, **kwargs)
#    1437           ret = tf_session.TF_SessionRunCallable(
#    1438               self._session._session, self._handle, args, status,
# -> 1439               run_metadata_ptr)
#    1440         if run_metadata:
#    1441           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:

# %%
plt.plot(history.history['loss'], label='train_loss')
plt.plot(history.history['val_loss'], 'r', label='val_loss')
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend()
plt.show()

plt.plot(history.history['accuracy'], label='train_acc')
plt.plot(history.history['val_accuracy'], 'r', label='val_acc')
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend()
plt.show()

# %%
with open('history/img_aug', 'wb') as file_pi:
    pickle.dump(history.history, file_pi)

# %% [markdown]
# # Make More Layers Trainable

# %%
model=Model(inputs=base_model.input,outputs=preds)

# %%
model.summary()
# Out:
# Model: "model_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         (None, None, None, 3)     0
# _________________________________________________________________
# conv1_pad (ZeroPadding2D)    (None, None, None, 3)     0
# _________________________________________________________________
# conv1 (Conv2D)               (None, None, None, 32)    864
# _________________________________________________________________
# conv1_bn (BatchNormalization (None, None, None, 32)    128
# _________________________________________________________________
# conv1_relu (ReLU)            (None, None, None, 32)    0
# _________________________________________________________________
# conv_dw_1 (DepthwiseConv2D)  (None, None, None, 32)    288
# _________________________________________________________________
# conv_dw_1_bn (BatchNormaliza (None, None, None, 32)    128
# _________________________________________________________________
# conv_dw_1_relu (ReLU)        (None, None, None, 32)    0
# _________________________________________________________________
# conv_pw_1 (Conv2D)           (None, None, None, 64)    2048
# _________________________________________________________________
# conv_pw_1_bn (BatchNormaliza (None, None, None, 64)    256
# _________________________________________________________________
# conv_pw_1_relu (ReLU)        (None, None, None, 64)    0
# _________________________________________________________________
# conv_pad_2 (ZeroPadding2D)   (None, None, None, 64)    0
# _________________________________________________________________
# conv_dw_2 (DepthwiseConv2D)  (None, None, None, 64)    576
# _________________________________________________________________
# conv_dw_2_bn (BatchNormaliza (None, None, None, 64)    256
# _________________________________________________________________
# conv_dw_2_relu (ReLU)        (None, None, None, 64)    0
# _________________________________________________________________
# conv_pw_2 (Conv2D)           (None, None, None, 128)   8192
# _________________________________________________________________
# conv_pw_2_bn (BatchNormaliza (None, None, None, 128)   512
# _________________________________________________________________
# conv_pw_2_relu (ReLU)        (None, None, None, 128)   0
# _________________________________________________________________
# conv_dw_3 (DepthwiseConv2D)  (None, None, None, 128)   1152
# _________________________________________________________________
# conv_dw_3_bn (BatchNormaliza (None, None, None, 128)   512
# _________________________________________________________________
# conv_dw_3_relu (ReLU)        (None, None, None, 128)   0
# _________________________________________________________________
# conv_pw_3 (Conv2D)           (None, None, None, 128)   16384
# _________________________________________________________________
# conv_pw_3_bn (BatchNormaliza (None, None, None, 128)   512
# _________________________________________________________________
# conv_pw_3_relu (ReLU)        (None, None, None, 128)   0
# _________________________________________________________________
# conv_pad_4 (ZeroPadding2D)   (None, None, None, 128)   0
# _________________________________________________________________
# conv_dw_4 (DepthwiseConv2D)  (None, None, None, 128)   1152
# _________________________________________________________________
# conv_dw_4_bn (BatchNormaliza (None, None, None, 128)   512
# _________________________________________________________________
# conv_dw_4_relu (ReLU)        (None, None, None, 128)   0
# _________________________________________________________________
# conv_pw_4 (Conv2D)           (None, None, None, 256)   32768
# _________________________________________________________________
# conv_pw_4_bn (BatchNormaliza (None, None, None, 256)   1024
# _________________________________________________________________
# conv_pw_4_relu (ReLU)        (None, None, None, 256)   0
# _________________________________________________________________
# conv_dw_5 (DepthwiseConv2D)  (None, None, None, 256)   2304
# _________________________________________________________________
# conv_dw_5_bn (BatchNormaliza (None, None, None, 256)   1024
# _________________________________________________________________
# conv_dw_5_relu (ReLU)        (None, None, None, 256)   0
# _________________________________________________________________
# conv_pw_5 (Conv2D)           (None, None, None, 256)   65536
# _________________________________________________________________
# conv_pw_5_bn (BatchNormaliza (None, None, None, 256)   1024
# _________________________________________________________________
# conv_pw_5_relu (ReLU)        (None, None, None, 256)   0
# _________________________________________________________________
# conv_pad_6 (ZeroPadding2D)   (None, None, None, 256)   0
# _________________________________________________________________
# conv_dw_6 (DepthwiseConv2D)  (None, None, None, 256)   2304
# _________________________________________________________________
# conv_dw_6_bn (BatchNormaliza (None, None, None, 256)   1024
# _________________________________________________________________
# conv_dw_6_relu (ReLU)        (None, None, None, 256)   0
# _________________________________________________________________
# conv_pw_6 (Conv2D)           (None, None, None, 512)   131072
# _________________________________________________________________
# conv_pw_6_bn (BatchNormaliza (None, None, None, 512)   2048
# _________________________________________________________________
# conv_pw_6_relu (ReLU)        (None, None, None, 512)   0
# _________________________________________________________________
# conv_dw_7 (DepthwiseConv2D)  (None, None, None, 512)   4608
# _________________________________________________________________
# conv_dw_7_bn (BatchNormaliza (None, None, None, 512)   2048
# _________________________________________________________________
# conv_dw_7_relu (ReLU)        (None, None, None, 512)   0
# _________________________________________________________________
# conv_pw_7 (Conv2D)           (None, None, None, 512)   262144
# _________________________________________________________________
# conv_pw_7_bn (BatchNormaliza (None, None, None, 512)   2048
# _________________________________________________________________
# conv_pw_7_relu (ReLU)        (None, None, None, 512)   0
# _________________________________________________________________
# conv_dw_8 (DepthwiseConv2D)  (None, None, None, 512)   4608
# _________________________________________________________________
# conv_dw_8_bn (BatchNormaliza (None, None, None, 512)   2048
# _________________________________________________________________
# conv_dw_8_relu (ReLU)        (None, None, None, 512)   0
# _________________________________________________________________
# conv_pw_8 (Conv2D)           (None, None, None, 512)   262144
# _________________________________________________________________
# conv_pw_8_bn (BatchNormaliza (None, None, None, 512)   2048
# _________________________________________________________________
# conv_pw_8_relu (ReLU)        (None, None, None, 512)   0
# _________________________________________________________________
# conv_dw_9 (DepthwiseConv2D)  (None, None, None, 512)   4608
# _________________________________________________________________
# conv_dw_9_bn (BatchNormaliza (None, None, None, 512)   2048
# _________________________________________________________________
# conv_dw_9_relu (ReLU)        (None, None, None, 512)   0
# _________________________________________________________________
# conv_pw_9 (Conv2D)           (None, None, None, 512)   262144
# _________________________________________________________________
# conv_pw_9_bn (BatchNormaliza (None, None, None, 512)   2048
# _________________________________________________________________
# conv_pw_9_relu (ReLU)        (None, None, None, 512)   0
# _________________________________________________________________
# conv_dw_10 (DepthwiseConv2D) (None, None, None, 512)   4608
# _________________________________________________________________
# conv_dw_10_bn (BatchNormaliz (None, None, None, 512)   2048
# _________________________________________________________________
# conv_dw_10_relu (ReLU)       (None, None, None, 512)   0
# _________________________________________________________________
# conv_pw_10 (Conv2D)          (None, None, None, 512)   262144
# _________________________________________________________________
# conv_pw_10_bn (BatchNormaliz (None, None, None, 512)   2048
# _________________________________________________________________
# conv_pw_10_relu (ReLU)       (None, None, None, 512)   0
# _________________________________________________________________
# conv_dw_11 (DepthwiseConv2D) (None, None, None, 512)   4608
# _________________________________________________________________
# conv_dw_11_bn (BatchNormaliz (None, None, None, 512)   2048
# _________________________________________________________________
# conv_dw_11_relu (ReLU)       (None, None, None, 512)   0
# _________________________________________________________________
# conv_pw_11 (Conv2D)          (None, None, None, 512)   262144
# _________________________________________________________________
# conv_pw_11_bn (BatchNormaliz (None, None, None, 512)   2048
# _________________________________________________________________
# conv_pw_11_relu (ReLU)       (None, None, None, 512)   0
# _________________________________________________________________
# conv_pad_12 (ZeroPadding2D)  (None, None, None, 512)   0
# _________________________________________________________________
# conv_dw_12 (DepthwiseConv2D) (None, None, None, 512)   4608
# _________________________________________________________________
# conv_dw_12_bn (BatchNormaliz (None, None, None, 512)   2048
# _________________________________________________________________
# conv_dw_12_relu (ReLU)       (None, None, None, 512)   0
# _________________________________________________________________
# conv_pw_12 (Conv2D)          (None, None, None, 1024)  524288
# _________________________________________________________________
# conv_pw_12_bn (BatchNormaliz (None, None, None, 1024)  4096
# _________________________________________________________________
# conv_pw_12_relu (ReLU)       (None, None, None, 1024)  0
# _________________________________________________________________
# conv_dw_13 (DepthwiseConv2D) (None, None, None, 1024)  9216
# _________________________________________________________________
# conv_dw_13_bn (BatchNormaliz (None, None, None, 1024)  4096
# _________________________________________________________________
# conv_dw_13_relu (ReLU)       (None, None, None, 1024)  0
# _________________________________________________________________
# conv_pw_13 (Conv2D)          (None, None, None, 1024)  1048576
# _________________________________________________________________
# conv_pw_13_bn (BatchNormaliz (None, None, None, 1024)  4096
# _________________________________________________________________
# conv_pw_13_relu (ReLU)       (None, None, None, 1024)  0
# _________________________________________________________________
# global_average_pooling2d_5 ( (None, 1024)              0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 2)                 2050
# =================================================================
# Total params: 3,230,914
# Trainable params: 3,209,026
# Non-trainable params: 21,888
# _________________________________________________________________

# %%
n_trainable_layers = 9

for layer in model.layers[:-n_trainable_layers]:
    layer.trainable=False

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
img_datagen=ImageDataGenerator(preprocessing_function=preprocess_input, validation_split=0.3) #included in our dependencies

train_generator=img_datagen.flow_from_directory('./leaf',
                                                target_size=(224,224),
                                                color_mode='rgb',
                                                batch_size=128,
                                                class_mode='categorical',
                                                shuffle=True,
                                                subset='training')
# Out:
# Found 243 images belonging to 2 classes.

# %%
test_generator=img_datagen.flow_from_directory('./leaf',
                                               target_size=(224,224),
                                               color_mode='rgb',
                                               batch_size=64,
                                               class_mode='categorical',
                                               shuffle=True,
                                               subset='validation')
# Out:
# Found 102 images belonging to 2 classes.

# %%
step_size_train=train_generator.n//train_generator.batch_size
history = model.fit_generator(generator=train_generator,
                              validation_data=test_generator,
                              steps_per_epoch=step_size_train,
                              epochs=25)
# Out:
# Epoch 1/25
# 1/1 [==============================] - 13s 13s/step - loss: 1.1302 - accuracy: 0.4844 - val_loss: 0.1745 - val_accuracy: 0.9118
# Epoch 2/25
# 1/1 [==============================] - 8s 8s/step - loss: 0.3104 - accuracy: 0.9043 - val_loss: 0.1811 - val_accuracy: 0.9314
# Epoch 3/25
# 1/1 [==============================] - 9s 9s/step - loss: 0.0324 - accuracy: 0.9922 - val_loss: 0.1272 - val_accuracy: 0.8824
# Epoch 4/25
# 1/1 [==============================] - 8s 8s/step - loss: 0.0603 - accuracy: 0.9739 - val_loss: 0.1853 - val_accuracy: 0.8922
# Epoch 5/25
# 1/1 [==============================] - 8s 8s/step - loss: 0.0295 - accuracy: 0.9913 - val_loss: 0.3912 - val_accuracy: 0.8333
# Epoch 6/25
# 1/1 [==============================] - 10s 10s/step - loss: 0.0049 - accuracy: 1.0000 - val_loss: 0.6540 - val_accuracy: 0.7647
# Epoch 7/25
# 1/1 [==============================] - 9s 9s/step - loss: 0.0056 - accuracy: 1.0000 - val_loss: 0.3364 - val_accuracy: 0.7549
# Epoch 8/25
# 1/1 [==============================] - 9s 9s/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.8687 - val_accuracy: 0.7255
# Epoch 9/25
# 1/1 [==============================] - 10s 10s/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.4982 - val_accuracy: 0.7353
# Epoch 10/25
# 1/1 [==============================] - 9s 9s/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.6040 - val_accuracy: 0.7353
# Epoch 11/25
# 1/1 [==============================] - 9s 9s/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.7606 - val_accuracy: 0.7451
# Epoch 12/25
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-81-a5105dc04268> in <module>
#       3                               validation_data=test_generator,
#       4                               steps_per_epoch=step_size_train,
# ----> 5                               epochs=25)
#
# ~/opt/anaconda3/envs/tree-classifier/lib/python3.6/site-packages/keras/legacy/interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name + '` call to the ' +
#      90                               'Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# ~/opt/anaconda3/envs/tree-classifier/lib/python3.6/site-packages/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1730             use_multiprocessing=use_multiprocessing,
#    1731             shuffle=shuffle,
# -> 1732             initial_epoch=initial_epoch)
#    1733
#    1734     @interfaces.legacy_generator_methods_support
#
# ~/opt/anaconda3/envs/tree-classifier/lib/python3.6/site-packages/keras/engine/training_generator.py in fit_generator(model, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#     218                                             sample_weight=sample_weight,
#     219                                             class_weight=class_weight,
# --> 220                                             reset_metrics=False)
#     221
#     222                 outs = to_list(outs)
#
# ~/opt/anaconda3/envs/tree-classifier/lib/python3.6/site-packages/keras/engine/training.py in train_on_batch(self, x, y, sample_weight, class_weight, reset_metrics)
#    1512             ins = x + y + sample_weights
#    1513         self._make_train_function()
# -> 1514         outputs = self.train_function(ins)
#    1515
#    1516         if reset_metrics:
#
# ~/opt/anaconda3/envs/tree-classifier/lib/python3.6/site-packages/tensorflow/python/keras/backend.py in __call__(self, inputs)
#    3074
#    3075     fetched = self._callable_fn(*array_vals,
# -> 3076                                 run_metadata=self.run_metadata)
#    3077     self._call_fetch_callbacks(fetched[-len(self._fetches):])
#    3078     return nest.pack_sequence_as(self._outputs_structure,
#
# ~/opt/anaconda3/envs/tree-classifier/lib/python3.6/site-packages/tensorflow/python/client/session.py in __call__(self, *args, **kwargs)
#    1437           ret = tf_session.TF_SessionRunCallable(
#    1438               self._session._session, self._handle, args, status,
# -> 1439               run_metadata_ptr)
#    1440         if run_metadata:
#    1441           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:

# %%
plt.plot(history.history['loss'], label='train_loss')
plt.plot(history.history['val_loss'], 'r', label='val_loss')
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend()
plt.show()

plt.plot(history.history['accuracy'], label='train_acc')
plt.plot(history.history['val_accuracy'], 'r', label='val_acc')
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-7ff3725edb98> in <module>
# ----> 1 plt.plot(history.history['loss'], label='train_loss')
#       2 plt.plot(history.history['val_loss'], 'r', label='val_loss')
#       3 plt.title('Model loss')
#       4 plt.ylabel('Loss')
#       5 plt.xlabel('Epoch')
#
# NameError: name 'plt' is not defined

# %% [markdown]
# # Human Judgement on the Prediction Results

# %%
train_generator.class_indices
# Out:
# {'coniferous': 0, 'deciduous': 1}

# %%
p = Path('./data/raw/deciduous/')
img_paths = list(p.glob('*.jpg'))
for path in img_paths[:10]:
    x = load_img_and_transfer(path, im_show=True)
    preds = model.predict(x)
    print(preds[0])
# Out:
# [9.3687021e-07 9.9999905e-01]
# [1.2632363e-05 9.9998736e-01]
# [1.0830373e-04 9.9989164e-01]
# [1.3882483e-08 1.0000000e+00]
# [0.88970333 0.11029668]
# [1.7276601e-08 1.0000000e+00]
# [0.0322594  0.96774065]
# [7.8948024e-06 9.9999213e-01]
# [8.1491111e-05 9.9991846e-01]
# [1.2568364e-07 9.9999988e-01]

# %% [markdown]
# # TODO
# * Output image patterns
# * Make more layer trainable
# * Try a different model architecture
# * Replace the output layer only
# * Try other weights (imagenet is currently used)
# * Tune learning rate of the optimizer
